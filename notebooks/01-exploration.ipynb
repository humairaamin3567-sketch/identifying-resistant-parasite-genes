# %% [markdown]
# # 01 - Exploration

# %%
# List FASTA files and preview sequences
from pathlib import Path
from Bio import SeqIO
p=Path('data/raw')
for f in p.glob('*.fasta'):
    print(f.name)
    for r in SeqIO.parse(f, 'fasta'):
        print(len(r.seq))
        break
