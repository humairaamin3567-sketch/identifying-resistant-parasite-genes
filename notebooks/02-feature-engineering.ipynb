# %% [markdown]
# # 02 - Feature Engineering

# %%
# Run feature extraction
# !python src/features.py --fasta-dir data/raw --meta data/metadata.csv --out data/processed/features.csv --k 3 --top-kmers 200
